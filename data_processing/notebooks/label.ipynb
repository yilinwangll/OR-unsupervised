# %%
import json
data = [json.loads(line) for line in open('/home/work/mllm_datas/yilin/code/OR-SR1/datasets/label_data/retrieved_2/generated.jsonl', 'r', encoding='utf-8')]
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'video (Python 3.10.19)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data[0]
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'video (Python 3.10.19)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
